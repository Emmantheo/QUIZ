# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as mlt
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data = pd.read_csv(url)
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.groupby('fuel_type_code_pudl')['fuel_type_code_pudl'].count()
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: fuel_type_code_pudl, dtype: int64

# %%
fuel_data.groupby('fuel_data_code_pudl')['fuel_cost_per_unit_burned'].mean()

# %%
fuel_typgrp = fuel_data.groupby('fuel_type_code_pudl')
fuel_typgrp.get_group('coal')
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# ...                         ...               ...          ...
# 29503  f1_fuel_2018_12_191_1_14               191         2018
# 29510   f1_fuel_2018_12_403_0_2               403         2018
# 29516    f1_fuel_2018_12_12_0_8                12         2018
# 29517   f1_fuel_2018_12_12_0_10                12         2018
# 29521   f1_fuel_2018_12_12_1_13                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_typgrp['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
df = fuel_data
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
missing_data = df.isnull()
missing_data.head(50)
# Out:
#     record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# 0       False             False        False             False
# 1       False             False        False             False
# 2       False             False        False             False
# 3       False             False        False             False
# 4       False             False        False             False
# 5       False             False        False             False
# 6       False             False        False             False
# 7       False             False        False             False
# 8       False             False        False             False
# 9       False             False        False             False
# 10      False             False        False             False
# 11      False             False        False             False
# 12      False             False        False             False
# 13      False             False        False             False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column]).count()
# Out:
# record_id
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29518    False
# 29519    False
# 29520    False
# 29521    False
# 29522    False
# Name: record_id, Length: 29523, dtype: bool
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-8b398a6d631a> in <module>
#       1 for column in missing_data.columns.values.tolist():
#       2     print(column)
# ----> 3     print(missing_data[column]).count()
#
# AttributeError: 'NoneType' object has no attribute 'count'

# %%
fuel_typgrp.mean()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                       115.637534  2004.623143     1.903473e+06
# gas                        124.122062  2005.978060     4.843183e+06
# nuclear                    107.397311  2002.970660     5.454838e+06
# oil                        113.236235  2007.195933     6.311677e+04
# other                      110.467066  2001.700599     2.948137e+06
# waste                      154.253968  2005.650794     1.171914e+05
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                           20.762780                  67.421830
# gas                             1.021913                  13.659397
# nuclear                        17.582120                4955.157002
# oil                             5.814377                 168.877086
# other                           0.572752                  18.253856
# ...

# %%
fuel_typgrp
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: report_year, dtype: int64
